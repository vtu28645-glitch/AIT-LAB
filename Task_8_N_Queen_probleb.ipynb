# %% [markdown]
# <a href="https://colab.research.google.com/github/vtu28645-glitch/AIT-LAB/blob/main/Task_8_N_Queen_probleb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
N = 4
board = [-1] * N

def safe(row, col):
    for i in range(row):
        if board[i] == col or abs(board[i] - col) == abs(i - row):
            return False
    return True
def solve(row):
    if row == N:
        return True
    for c_col in range(N):
        if safe(row, c_col):
            board[row] = c_col
            if solve(row + 1):
                return True
            board[row] = -1
    return False
if solve(0):
    for i in range(N):
        print("".join("Q" if board[i] == j else "." for j in range(N)))
# Out:
# .Q..
# ...Q
# Q...
# ..Q.
