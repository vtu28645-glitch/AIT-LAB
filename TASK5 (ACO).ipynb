# %% [markdown]
# <a href="https://colab.research.google.com/github/vtu28645-glitch/AIT-LAB/blob/main/TASK5%20(ACO).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
R1 = 30
R2 = 70
Total = R1 + R2
P1 = R1 / Total
p2 = R2 / Total
print("R1", R1)
print("R2", R2)
print("total=", Total)
print("P1=", P1)
print("P2=", p2)
if P1 > P2:
  print("Best route :R1")
else:
  print("Best route:R2")
print("P1+P2=", P1 + p2)
# Out:
# R1 30
# R2 70
# total= 100
# P1= 0.3
# P2= 0.7
# Best route:R2
# P1+P2= 1.0
