# %% [markdown]
# <a href="https://colab.research.google.com/github/vtu28645-glitch/AIT-LAB/blob/main/monkey%20banana%20problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
monkey = "window"
box = "window"
banana = False
print("monkey walks to box")
print("monkey pushes box under bananas")
box ="under banana"
print("monkey climbs box")
print("monkey grasps banana")
banana = True
print("goal achieved:",banana)
# Out:
# monkey walks to box
# monkey pushes box under bananas
# monkey climbs box
# monkey grasps banana
# goal achieved: True
